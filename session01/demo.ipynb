# %%
# Cú pháp: tên_biến toán tử gắn giá trị
firstNumber = 10

# %%
#In ra giá trị của biến firstNumber
print(firstNumber)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #In ra giá trị của biến firstNumber
# ----> 2 print(firstNumber)
#
# NameError: name 'firstNumber' is not defined
